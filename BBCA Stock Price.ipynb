# %% [markdown]
# <a href="https://colab.research.google.com/github/Kittsxy/bank-stock-prediction-lstm/blob/main/BBCA%20Stock%20Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import sqrt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import datetime as dt
from datetime import datetime
import seaborn as sns
import math
import pickle
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Bidirectional, Flatten, Dense
from keras.regularizers import l1
from keras.regularizers import l2
from keras.regularizers import L1L2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from keras.layers import LSTM
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from keras.regularizers import l1_l2
from tensorflow.keras.layers import Dense, Bidirectional, GRU, LSTM
from tensorflow.keras.regularizers import l1_l2

# %%
from statistics import stdev

def Average(data):
    return sum(data) / len(data)

# Z-Scores
def normalize_series(data, mean, std):
    data = data - mean
    data = data / std
    return data

def inverse_normalize_series(data, mean, std):
    data = data * std
    data = data + mean
    return data

# %%
def model_forecast(model, series, window_size, batch_size):
   ds = tf.data.Dataset.from_tensor_slices(series)
   ds = ds.window(window_size, shift=1, drop_remainder=True)
   ds = ds.flat_map(lambda w: w.batch(window_size))
   ds = ds.batch(batch_size, drop_remainder=True).prefetch(1)
   forecast = model.predict(ds)
   return forecast

# %%
# Datetime
def datetime_range(start, end, delta):
    current = start
    while current < end:
        yield current
        current += delta

# %%
# Multisteps Forecast
def multi_step_forecasts(n_lookback, n_forecast, model, data, data_scaled):

    input_forecast = data_scaled[-n_lookback:]
    x_forecast = input_forecast.reshape(1, n_lookback, 1)

    y_future = [] # predicted target values

    for i in range(n_forecast):
        # generate the next forecast
        output = model.predict(x_forecast)

        # transform the forecasts back to the original scale
        normal_output = inverse_normalize_series(output, Average(data), stdev(data.flatten()))

        # save the forecast
        y_future.append(list(normal_output[0]))

        # feed the last forecast back to the model as an input
        x_forecast = np.append(x_forecast, output.flatten()[0])

        # reshape to fit the input model
        x_forecast = x_forecast[-n_lookback:].reshape(1, n_lookback, 1)


    return y_future

# %%
df = pd.read_csv("/content/BBCA.JK Close.csv",sep=";")

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)
df.info()
# Out:
# <ipython-input-7-fe3be03317d7>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = df['Date'].apply(pd.to_datetime)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2726 entries, 0 to 2725
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2726 non-null   datetime64[ns]
#  1   Close   2726 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 42.7 KB

# %%
df.head()
# Out:
#         Date  Close
# 0 2013-02-01   1820
# 1 2013-03-01   1830
# 2 2013-04-01   1810
# 3 2013-07-01   1840
# 4 2013-08-01   1830

# %%
dataSize = len(df)
print(dataSize)
# Out:
# 2726

# %%
# Membuat date sequence

dataset_date = [dt.strftime('%Y-%m-%d') for dt in
       datetime_range(datetime(2013,2,1), datetime(2023,12,29),
       relativedelta(days=1))]

print(len(df))
print(np.shape(dataset_date))
# Out:
# 2726
# (3983,)

# %%
# Mengonversi Skalar/Array/Series Menjadi Objek DateTime
# Ensure that the length of dataset_date matches the length of df
#dataset_date = dataset_date[:len(df)]  # Trim dataset_date to match df length

#df['Date'] = dataset_date
#df['Date'] = df['Date'].apply(pd.to_datetime)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2726 entries, 0 to 2725
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2726 non-null   datetime64[ns]
#  1   Close   2726 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 42.7 KB

# %%
# Plot Data
plt.subplots(figsize=(15, 6))
sns.lineplot(x="Date", y="Close", data=df, label='Harga Saham BBCA')
plt.xlabel('Periode Waktu')
plt.ylabel('Harga Saham')
plt.legend(loc='upper left', prop={'size': 16})
plt.grid()
plt.show()

# %%
# Mengetahui Summary dari Dataset
df.describe()
# Out:
#                                 Date        Close
# count                           2726  2726.000000
# mean   2018-06-30 05:27:30.770359296  4876.456346
# min              2013-01-02 00:00:00  1710.000000
# 25%              2015-10-13 12:00:00  2660.000000
# 50%              2018-06-30 12:00:00  4667.500000
# 75%              2021-03-17 18:00:00  6568.750000
# max              2023-12-29 00:00:00  9400.000000
# std                              NaN  2287.716799

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df['Close'],lags=25)

# %%
# Menentukan Timestep yang Akan Dipakai
n_lookback = 60

# %%
# Menentukan Proporsi Pembagian Data Training dan Data Testing
SPLIT_TIME_TRAIN_VAL = int(math.floor(0.75*((len(df))/n_lookback)) * n_lookback)
SPLIT_TIME_TRAIN_VAL
# Out:
# 2040

# %%
data_train = df[:SPLIT_TIME_TRAIN_VAL]['Close']
data_train = pd.DataFrame(data_train)
data_train.index = df[:SPLIT_TIME_TRAIN_VAL]['Date']

data_val = df[SPLIT_TIME_TRAIN_VAL:]['Close']
data_val = pd.DataFrame(data_val)
data_val.index = df[SPLIT_TIME_TRAIN_VAL:]['Date']

print(len(data_train)/len(df))
print(len(data_val)/len(df))
# Out:
# 0.7483492296404989
# 0.2516507703595011

# %%
# Melihat Data Training/Pelatihan
data_train.head()
# Out:
#             Close
# Date
# 2013-02-01   1820
# 2013-03-01   1830
# 2013-04-01   1810
# 2013-07-01   1840
# 2013-08-01   1830

# %%
# Plot Pembagian Data Training dan Data Testing
plt.subplots(figsize = (18,6))
ax=sns.lineplot(x="Date", y="Close",
             data=data_train, drawstyle='steps-post', label='Data Pelatihan')
ax=sns.lineplot(x="Date", y="Close",
             data=data_val, drawstyle='steps-post', label='Data Pengujian')
plt.legend(loc='upper left', prop={'size': 16})
plt.xlabel('Tahun', fontsize=15); plt.ylabel('Harga Saham BBCA', fontsize=15)
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
plt.grid()

# %%
# Mengubah Dimensi Dataset
bbca = df["Close"].values.reshape(-1, 1)

bbca_train = data_train.values.reshape(-1, 1)

bbca_val = data_val.values.reshape(-1, 1)

print(bbca_train.shape);print(bbca_val.shape)
# Out:
# (2040, 1)
# (686, 1)

# %%
# Melihat Data Pelatihan yang Sudah Diubah Dimensinya
bbca_train[:5]
# Out:
# array([[1820],
#        [1830],
#        [1810],
#        [1840],
#        [1830]])

# %%
# Membuat Variabel Baru x_train dan y_train
x_train = []
y_train = []

for i in range(n_lookback, len(bbca_train)):
    x_train.append(bbca_train[i - n_lookback: i])
    y_train.append(bbca_train[i])

x_train = np.array(x_train)
y_train = np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (1980, 60, 1)
# (1980, 1)

# %%
# Membuat Variabel Baru x_val dan y_val
x_val = []
y_val = []

for i in range(n_lookback, len(bbca_val)):
    x_val.append(bbca_val[i - n_lookback: i])
    y_val.append(bbca_val[i])

x_val = np.array(x_val)
y_val = np.array(y_val)
print(x_val.shape)
print(y_val.shape)
# Out:
# (626, 60, 1)
# (626, 1)

# %%
# Scalling Dataset
bbca_scaled = normalize_series(bbca, Average(bbca), stdev(bbca.flatten()))

bbca_train_scaled = normalize_series(bbca_train, Average(bbca_train), stdev(bbca_train.flatten()))

bbca_val_scaled = normalize_series(bbca_val, Average(bbca_val), stdev(bbca_val.flatten()))

# %%
# Data Sebelum Dilakukan Scalling
bbca[0:5]
# Out:
# array([[1820],
#        [1830],
#        [1810],
#        [1840],
#        [1830]])

# %%
# Data Sesudah Dilakukan Scalling
bbca_scaled[0:5]
# Out:
# array([[-1.33602918],
#        [-1.33165801],
#        [-1.34040035],
#        [-1.32728684],
#        [-1.33165801]])

# %%
# Membuat Feature dan label Untuk Data Pelatihan Dari Data yang Sudah Discalling
x_train_scaled = []
y_train_scaled = []

for i in range(n_lookback, len(bbca_train_scaled)):
    x_train_scaled.append(bbca_train_scaled[i - n_lookback: i])
    y_train_scaled.append(bbca_train_scaled[i])

x_train_scaled = np.array(x_train_scaled)
y_train_scaled = np.array(y_train_scaled)
print(x_train_scaled.shape)
print(y_train_scaled.shape)
# Out:
# (1980, 60, 1)
# (1980, 1)

# %%
# Melihat Dimensi Dari Data Pertama
print(x_train[0].shape)
# Out:
# (60, 1)

# %%
# Membuat Feature dan label Untuk Data Pengujian Dari Data yang Sudah Di scalling
x_val_scaled = []
y_val_scaled = []

for i in range(n_lookback, len(bbca_val_scaled)):
    x_val_scaled.append(bbca_val_scaled[i - n_lookback: i])
    y_val_scaled.append(bbca_val_scaled[i])

x_val_scaled = np.array(x_val_scaled)
y_val_scaled = np.array(y_val_scaled)
print(x_val_scaled.shape)
print(y_val_scaled.shape)
# Out:
# (626, 60, 1)
# (626, 1)

# %%
# Membuat Arsitektur Model yang Akan Digunakan

# Model LSTM
model = Sequential()
model.add(LSTM(64, return_sequences=False, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.5), input_shape=(n_lookback,1)))
model.add(Dense(1))
model.compile(loss='huber', optimizer=Adam(learning_rate=0.00005))

# %%
# Menentukan File Tujuan Untuk Menyimpan Bobot Model
filepath = "best_model.h5"

# Membuat ModelCheckpoint Callback Untuk Menyimpan Bobot Model
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath,
                                                save_best_only=True,
                                                save_weights_only=True,
                                                monitor='val_loss',
                                                mode='min')

# Membuat Konfigurasi EarlyStopping Callback yang Berfungsi Untuk Memberhentikan Proses Training Ketika Nilai Loss Berhenti Membaik
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

# Fit the model to the data
history = model.fit(x_train_scaled, y_train_scaled, epochs=3000, validation_data=(x_val_scaled, y_val_scaled) ,batch_size=64,verbose=1, callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/3000
# 31/31 [==============================] - 2s 63ms/step - loss: 0.9767 - val_loss: 2023.7374
# Epoch 2/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.9337 - val_loss: 1232.8026
# Epoch 3/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.9015 - val_loss: 1016.6838
# Epoch 4/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.8718 - val_loss: 844.0898
# Epoch 5/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.8432 - val_loss: 605.2828
# Epoch 6/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.8158 - val_loss: 522.2166
# Epoch 7/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.7897 - val_loss: 329.2381
# Epoch 8/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.7645 - val_loss: 278.4291
# Epoch 9/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.7402 - val_loss: 235.3467
# Epoch 10/3000
# 31/31 [==============================] - 1s 44ms/step - loss: 0.7167 - val_loss: 169.9234
# Epoch 11/3000
# 31/31 [==============================] - 2s 59ms/step - loss: 0.6940 - val_loss: 152.3822
# Epoch 12/3000
# 31/31 [==============================] - 1s 47ms/step - loss: 0.6721 - val_loss: 112.4464
# Epoch 13/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.6509 - val_loss: 87.2625
# Epoch 14/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.6305 - val_loss: 67.0522
# Epoch 15/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.6106 - val_loss: 35.1995
# Epoch 16/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.5914 - val_loss: 29.8913
# Epoch 17/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.5727 - val_loss: 21.4396
# Epoch 18/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.5546 - val_loss: 19.9313
# Epoch 19/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.5368 - val_loss: 14.4742
# Epoch 20/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.5196 - val_loss: 9.3509
# Epoch 21/3000
# 31/31 [==============================] - 1s 48ms/step - loss: 0.5029 - val_loss: 7.4400
# Epoch 22/3000
# 31/31 [==============================] - 2s 55ms/step - loss: 0.4867 - val_loss: 5.1513
# Epoch 23/3000
# 31/31 [==============================] - 1s 41ms/step - loss: 0.4711 - val_loss: 3.6168
# Epoch 24/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.4558 - val_loss: 2.8099
# Epoch 25/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.4412 - val_loss: 2.0233
# Epoch 26/3000
# 31/31 [==============================] - 1s 42ms/step - loss: 0.4270 - val_loss: 1.6340
# Epoch 27/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.4132 - val_loss: 1.1990
# Epoch 28/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.3997 - val_loss: 1.0742
# Epoch 29/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.3867 - val_loss: 0.8121
# Epoch 30/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.3741 - val_loss: 0.7939
# Epoch 31/3000
# 31/31 [==============================] - 1s 45ms/step - loss: 0.3618 - val_loss: 0.6333
# Epoch 32/3000
# 31/31 [==============================] - 2s 54ms/step - loss: 0.3499 - val_loss: 0.5806
# Epoch 33/3000
# 31/31 [==============================] - 1s 46ms/step - loss: 0.3383 - val_loss: 0.5306
# Epoch 34/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.3270 - val_loss: 0.5053
# Epoch 35/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.3161 - val_loss: 0.4801
# Epoch 36/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.3055 - val_loss: 0.4302
# Epoch 37/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.2953 - val_loss: 0.4016
# Epoch 38/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.2853 - val_loss: 0.4126
# Epoch 39/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.2755 - val_loss: 0.3753
# Epoch 40/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.2663 - val_loss: 0.3730
# Epoch 41/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.2570 - val_loss: 0.3599
# Epoch 42/3000
# 31/31 [==============================] - 2s 50ms/step - loss: 0.2481 - val_loss: 0.3396
# Epoch 43/3000
# 31/31 [==============================] - 2s 60ms/step - loss: 0.2396 - val_loss: 0.3277
# Epoch 44/3000
# 31/31 [==============================] - 1s 40ms/step - loss: 0.2314 - val_loss: 0.3123
# Epoch 45/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.2232 - val_loss: 0.3080
# Epoch 46/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.2153 - val_loss: 0.2936
# Epoch 47/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.2076 - val_loss: 0.2688
# Epoch 48/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.2004 - val_loss: 0.2637
# Epoch 49/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.1932 - val_loss: 0.2482
# Epoch 50/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1861 - val_loss: 0.2377
# Epoch 51/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1794 - val_loss: 0.2312
# Epoch 52/3000
# 31/31 [==============================] - 1s 42ms/step - loss: 0.1728 - val_loss: 0.2195
# Epoch 53/3000
# 31/31 [==============================] - 3s 92ms/step - loss: 0.1666 - val_loss: 0.2131
# Epoch 54/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1603 - val_loss: 0.1964
# Epoch 55/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1546 - val_loss: 0.1965
# Epoch 56/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1485 - val_loss: 0.1916
# Epoch 57/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1431 - val_loss: 0.1888
# Epoch 58/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.1376 - val_loss: 0.1740
# Epoch 59/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.1325 - val_loss: 0.1725
# Epoch 60/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1273 - val_loss: 0.1617
# Epoch 61/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1224 - val_loss: 0.1678
# Epoch 62/3000
# 31/31 [==============================] - 1s 39ms/step - loss: 0.1180 - val_loss: 0.1523
# Epoch 63/3000
# 31/31 [==============================] - 2s 55ms/step - loss: 0.1130 - val_loss: 0.1465
# Epoch 64/3000
# 31/31 [==============================] - 2s 54ms/step - loss: 0.1086 - val_loss: 0.1440
# Epoch 65/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.1043 - val_loss: 0.1370
# Epoch 66/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.1001 - val_loss: 0.1329
# Epoch 67/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0963 - val_loss: 0.1260
# Epoch 68/3000
# 31/31 [==============================] - 1s 47ms/step - loss: 0.0924 - val_loss: 0.1265
# Epoch 69/3000
# 31/31 [==============================] - 2s 60ms/step - loss: 0.0887 - val_loss: 0.1223
# Epoch 70/3000
# 31/31 [==============================] - 1s 42ms/step - loss: 0.0852 - val_loss: 0.1166
# Epoch 71/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0816 - val_loss: 0.1115
# Epoch 72/3000
# 31/31 [==============================] - 1s 43ms/step - loss: 0.0782 - val_loss: 0.1098
# Epoch 73/3000
# 31/31 [==============================] - 2s 60ms/step - loss: 0.0749 - val_loss: 0.1076
# Epoch 74/3000
# 31/31 [==============================] - 1s 43ms/step - loss: 0.0718 - val_loss: 0.1038
# Epoch 75/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0689 - val_loss: 0.1003
# Epoch 76/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0660 - val_loss: 0.1030
# Epoch 77/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0632 - val_loss: 0.0928
# Epoch 78/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0604 - val_loss: 0.0930
# Epoch 79/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0578 - val_loss: 0.0905
# Epoch 80/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0558 - val_loss: 0.0856
# Epoch 81/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0532 - val_loss: 0.0858
# Epoch 82/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0509 - val_loss: 0.0867
# Epoch 83/3000
# 31/31 [==============================] - 2s 58ms/step - loss: 0.0488 - val_loss: 0.0817
# Epoch 84/3000
# 31/31 [==============================] - 2s 68ms/step - loss: 0.0468 - val_loss: 0.0758
# Epoch 85/3000
# 31/31 [==============================] - 2s 59ms/step - loss: 0.0451 - val_loss: 0.0788
# Epoch 86/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0429 - val_loss: 0.0796
# Epoch 87/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0412 - val_loss: 0.0709
# Epoch 88/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0395 - val_loss: 0.0686
# Epoch 89/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0377 - val_loss: 0.0681
# Epoch 90/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0361 - val_loss: 0.0727
# Epoch 91/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0347 - val_loss: 0.0658
# Epoch 92/3000
# 31/31 [==============================] - 1s 41ms/step - loss: 0.0331 - val_loss: 0.0688
# Epoch 93/3000
# 31/31 [==============================] - 2s 54ms/step - loss: 0.0316 - val_loss: 0.0650
# Epoch 94/3000
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0307 - val_loss: 0.0700
# Epoch 95/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0293 - val_loss: 0.0688
# Epoch 96/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0280 - val_loss: 0.0602
# Epoch 97/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0275 - val_loss: 0.0640
# Epoch 98/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0260 - val_loss: 0.0736
# Epoch 99/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0249 - val_loss: 0.0622
# Epoch 100/3000
# 31/31 [==============================] - 1s 43ms/step - loss: 0.0237 - val_loss: 0.0592
# Epoch 101/3000
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0228 - val_loss: 0.0566
# Epoch 102/3000
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0221 - val_loss: 0.0532
# Epoch 103/3000
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0230 - val_loss: 0.0542
# Epoch 104/3000
# 31/31 [==============================] - 2s 59ms/step - loss: 0.0212 - val_loss: 0.0520
# Epoch 105/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0202 - val_loss: 0.0504
# Epoch 106/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0191 - val_loss: 0.0508
# Epoch 107/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0192 - val_loss: 0.0502
# Epoch 108/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0177 - val_loss: 0.0504
# Epoch 109/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0173 - val_loss: 0.0474
# Epoch 110/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0166 - val_loss: 0.0507
# Epoch 111/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0162 - val_loss: 0.0460
# Epoch 112/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0157 - val_loss: 0.0441
# Epoch 113/3000
# 31/31 [==============================] - 1s 46ms/step - loss: 0.0150 - val_loss: 0.0444
# Epoch 114/3000
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0149 - val_loss: 0.0444
# Epoch 115/3000
# 31/31 [==============================] - 1s 46ms/step - loss: 0.0140 - val_loss: 0.0432
# Epoch 116/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0137 - val_loss: 0.0432
# Epoch 117/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0142 - val_loss: 0.0428
# Epoch 118/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0139 - val_loss: 0.0430
# Epoch 119/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0128 - val_loss: 0.0403
# Epoch 120/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0125 - val_loss: 0.0435
# Epoch 121/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0126 - val_loss: 0.0411
# Epoch 122/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0126 - val_loss: 0.0399
# Epoch 123/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0116 - val_loss: 0.0411
# Epoch 124/3000
# 31/31 [==============================] - 2s 53ms/step - loss: 0.0110 - val_loss: 0.0389
# Epoch 125/3000
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0112 - val_loss: 0.0383
# Epoch 126/3000
# 31/31 [==============================] - 1s 39ms/step - loss: 0.0109 - val_loss: 0.0398
# Epoch 127/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0112 - val_loss: 0.0384
# Epoch 128/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0110 - val_loss: 0.0387
# Epoch 129/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0108 - val_loss: 0.0401
# Epoch 130/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0102 - val_loss: 0.0413
# Epoch 131/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0103 - val_loss: 0.0406
# Epoch 132/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0102 - val_loss: 0.0411
# Epoch 133/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0100 - val_loss: 0.0380
# Epoch 134/3000
# 31/31 [==============================] - 1s 44ms/step - loss: 0.0106 - val_loss: 0.0370
# Epoch 135/3000
# 31/31 [==============================] - 2s 55ms/step - loss: 0.0097 - val_loss: 0.0382
# Epoch 136/3000
# 31/31 [==============================] - 2s 56ms/step - loss: 0.0098 - val_loss: 0.0367
# Epoch 137/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0096 - val_loss: 0.0377
# Epoch 138/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0093 - val_loss: 0.0385
# Epoch 139/3000
# 31/31 [==============================] - 1s 36ms/step - loss: 0.0095 - val_loss: 0.0377
# Epoch 140/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0092 - val_loss: 0.0367
# Epoch 141/3000
# 31/31 [==============================] - 1s 38ms/step - loss: 0.0097 - val_loss: 0.0359
# Epoch 142/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0094 - val_loss: 0.0414
# Epoch 143/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0091 - val_loss: 0.0372
# Epoch 144/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0089 - val_loss: 0.0362
# Epoch 145/3000
# 31/31 [==============================] - 1s 48ms/step - loss: 0.0092 - val_loss: 0.0385
# Epoch 146/3000
# 31/31 [==============================] - 2s 54ms/step - loss: 0.0089 - val_loss: 0.0399
# Epoch 147/3000
# 31/31 [==============================] - 1s 45ms/step - loss: 0.0087 - val_loss: 0.0361
# Epoch 148/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0090 - val_loss: 0.0374
# Epoch 149/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0087 - val_loss: 0.0402
# Epoch 150/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0089 - val_loss: 0.0411
# Epoch 151/3000
# 31/31 [==============================] - 1s 37ms/step - loss: 0.0088 - val_loss: 0.0377

# %%
# Plot Loss Dari Model Peramalan
plt.figure(figsize=[18,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss','Validation loss'],fontsize=18)
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Training and Validation loss',fontsize=16)
plt.show()

# %%
forecast_train_data = model_forecast(model,bbca_train_scaled, n_lookback, 1)
print(forecast_train_data.shape)

forecast_train_data = forecast_train_data[:-1, 0]
print(forecast_train_data.shape)
print(bbca_train_scaled.shape[0]-n_lookback)
# Out:
# 1981/1981 [==============================] - 10s 5ms/step
# (1981, 1)
# (1980,)
# 1980

# %%
forecast_train_data = inverse_normalize_series(forecast_train_data, Average(bbca_train), stdev(bbca_train.flatten()))
forecast_train_data[:5]
# Out:
# array([2233.28546262, 2239.03851438, 2244.62103391, 2250.25604368,
#        2255.53045774])

# %%
actual = np.squeeze(bbca_train[-forecast_train_data.shape[0]:])
print(actual.shape)
print(actual[:5])
# Out:
# (1980,)
# [2200 2210 2240 2170 2210]

# %%
df_train = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_train['Date'] = data_train[-forecast_train_data.shape[0]:].index
df_train['Forecast'] = forecast_train_data
df_train['Actual'] = actual
df_train
# Out:
#            Date  Actual     Forecast
# 0    2013-01-04    2200  2233.285463
# 1    2013-02-04    2210  2239.038514
# 2    2013-03-04    2240  2244.621034
# 3    2013-04-04    2170  2250.256044
# 4    2013-05-04    2210  2255.530458
# ...         ...     ...          ...
# 1975 2021-03-03    7000  6460.210023
# 1976 2021-04-03    6720  6454.683168
# 1977 2021-05-03    6800  6449.347718
# 1978 2021-08-03    6720  6443.501283
# 1979 2021-09-03    6605  6435.984193
#
# [1980 rows x 3 columns]

# %%
plt.subplots(figsize=(18, 6))
ax = sns.lineplot(x="Date", y="Actual", data=df_train,
                    label="Data Latih Aktual", marker='.', color = 'red')
ax = sns.lineplot(x="Date", y="Forecast", data=df_train,
                    label="Prakiraan Data Latih", marker='.', linestyle="--", color = 'darkslateblue')
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BBCA')
plt.title("Grafik Data Aktual dan Hasil Prakiraan dari Data Latih (Train Data)\n", fontsize = 15)
plt.legend(loc='upper left')

# %%
rmse = mean_squared_error(df_train['Forecast'], df_train['Actual'], squared=False)
mae = mean_absolute_error(df_train['Forecast'], df_train['Actual'])
mape = mean_absolute_percentage_error(df_train['Forecast'], df_train['Actual'])

print('Forecast Train Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Train Accuracy
# RMSE:  168.4812
# MAE:  119.1527
# MAPE:  0.032154

# %%
forecast_val_data = model_forecast(model, bbca_val_scaled, n_lookback, 1)
print(forecast_val_data.shape)

forecast_val_data = forecast_val_data[:-1, 0]
print(forecast_val_data.shape)
print(bbca_val_scaled.shape[0]-n_lookback)
# Out:
# 627/627 [==============================] - 4s 6ms/step
# (627, 1)
# (626,)
# 626

# %%
forecast_val_data = inverse_normalize_series(forecast_val_data, Average(bbca_val), stdev(bbca_val.flatten()))
forecast_val_data[:5]
# Out:
# array([6478587.84252426, 6488129.86944592, 6497094.41199596,
#        6505003.85060435, 6511789.77971104])

# %%
actual = np.squeeze(bbca_val[-forecast_val_data.shape[0]:])
print(actual.shape)
print(actual[:5])
# Out:
# (626,)
# [6470 6410 6470 6385 6330]

# %%
len(data_val[-forecast_val_data.shape[0]:])
# Out:
# 626

# %%
df_val = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_val['Date'] = data_val[-forecast_val_data.shape[0]:].index
df_val['Forecast'] = forecast_val_data
df_val['Actual'] = actual
df_val
# Out:
#           Date  Actual     Forecast
# 0   2021-11-06    6470  6477.831039
# 1   2021-06-14    6410  6487.383652
# 2   2021-06-15    6470  6496.358139
# 3   2021-06-16    6385  6504.276352
# 4   2021-06-17    6330  6511.069809
# ..         ...     ...          ...
# 621 2023-12-21    9325  8937.040207
# 622 2023-12-22    9325  8953.441574
# 623 2023-12-27    9375  8972.299911
# 624 2023-12-28    9400  8994.790024
# 625 2023-12-29    9400  9020.359116
#
# [626 rows x 3 columns]

# %%
plt.subplots(figsize=(18, 6))
ax = sns.lineplot(x="Date", y="Actual", data=df_val,
                    label="Data Validasi Aktual", marker='.', color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_val,
                    label="Prakiraan Data Validasi", marker='.', linestyle="--", color='darkslategrey')
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BBCA')
plt.title("Grafik Data Aktual dan Hasil Prakiraan dari Data Validasi (Validation Data)\n", fontsize = 15)
plt.legend(loc='upper left')

# %%
rmse = mean_squared_error(df_val['Forecast'], df_val['Actual'], squared=False)
mae = mean_absolute_error(df_val['Forecast'], df_val['Actual'])
mape = mean_absolute_percentage_error(df_val['Forecast'], df_val['Actual'])

print('Forecast Val Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Val Accuracy
# RMSE:  254.4016
# MAE:  204.5193
# MAPE:  0.026273

# %%
rmse = mean_squared_error(df_train['Forecast'], df_train['Actual'], squared=False)
mae = mean_absolute_error(df_train['Forecast'], df_train['Actual'])
mape = mean_absolute_percentage_error(df_train['Forecast'], df_train['Actual'])

print('Forecast Train Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))

rmse = mean_squared_error(df_val['Forecast'], df_val['Actual'], squared=False)
mae = mean_absolute_error(df_val['Forecast'], df_val['Actual'])
mape = mean_absolute_percentage_error(df_val['Forecast'], df_val['Actual'])

print('Forecast Val Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Train Accuracy
# RMSE:  168.4812
# MAE:  119.1527
# MAPE:  0.032154
# Forecast Val Accuracy
# RMSE:  254.4016
# MAE:  204.5193
# MAPE:  0.026273

# %%
# Meramalkan Untuk 15 Periode Ke Depan
forecast_values = multi_step_forecasts(n_lookback=n_lookback, n_forecast=727, model=model, data=bbca, data_scaled=bbca_scaled)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
# Rentang Tanggal Yang Akan Diramal
date_forecast = [dt.strftime('%Y-%m-%d') for dt in
       datetime_range(datetime(2024, 1, 2), datetime(2025, 12, 29),
       relativedelta(days=1))]

print(np.shape(date_forecast))
# Out:
# (727,)

# %%
# Hasil Peramalan
df_forecast = pd.DataFrame(columns=['Date', 'Forecast'])
df_forecast['Date'] = date_forecast
df_forecast['Date'] = pd.to_datetime(df_forecast['Date'])
df_forecast['Forecast'] = np.squeeze(forecast_values)
df_forecast
# Out:
#           Date     Forecast
# 0   2024-01-02  8748.037645
# 1   2024-01-03  8778.830126
# 2   2024-01-04  8796.626024
# 3   2024-01-05  8805.773729
# 4   2024-01-06  8805.502977
# ..         ...          ...
# 722 2025-12-24  8138.262254
# 723 2025-12-25  8138.262743
# 724 2025-12-26  8138.263719
# 725 2025-12-27  8138.263719
# 726 2025-12-28  8138.261522
#
# [727 rows x 2 columns]

# %%
# Plot Hasil Peramalan
from turtle import color

plt.subplots(figsize = (18,6))
sns.lineplot(x="Date", y="Forecast",
             data=df_forecast, marker='.', color = 'blue')
plt.title("Harga Saham BBCA 2 Januari 2024 - 29 Desember 2024")
plt.grid()

# %%
# Plot Data Aktual dan Hasil Peramalan
fig, ax = plt.subplots(figsize = (18,6))
ax = sns.lineplot(x="Date", y="Actual", data=df_train,
                    label="Data Latih Aktual", marker='.', color='red')
ax = sns.lineplot(x="Date", y="Forecast", data=df_train,
                    label="Prakiraan Data Latih", marker='.', linestyle="--", color='darkslateblue')
ax = sns.lineplot(x="Date", y="Actual", data=df_val,
                    label="Data Validasi Aktual", marker='.', color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_val,
                    label="Prakiraan Data Validasi", marker='.', linestyle="--", color='darkslategrey')
ax = sns.lineplot(x="Date", y="Forecast", data=df_forecast,
                    label="Hasil Prakiraan", marker='.', color = 'blue')
plt.grid()
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BBCA')
plt.title("Grafik Harga Saham BBCA\n", fontsize = 20)
plt.legend(loc='upper left')

# %%
fig, ax = plt.subplots(figsize = (18,6))
ax = sns.lineplot(x="Date", y="Close", data=df,
                    label="Data Aktual", color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_forecast,
                    label="Hasil Prakiraan", color='blue')
plt.title("Grafik Data Aktual dan Hasil Prakiraan\n", fontsize = 20)
plt.xlabel('Tahun'); plt.ylabel('Harga Saham BBCA')
plt.grid()
