# %% [markdown]
# <a href="https://colab.research.google.com/github/Kittsxy/bank-stock-prediction-lstm/blob/main/BMRI%20Stock%20Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy import sqrt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import MinMaxScaler
import datetime as dt
from datetime import datetime
import seaborn as sns
import math
import pickle
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from keras.models import Sequential
from keras.layers import Bidirectional, Flatten, Dense
from keras.regularizers import l1
from keras.regularizers import l2
from keras.regularizers import L1L2
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from keras.layers import LSTM
from tensorflow.keras import layers
from tensorflow.keras import regularizers
from keras.regularizers import l1_l2
from tensorflow.keras.layers import Dense, Bidirectional, GRU, LSTM
from tensorflow.keras.regularizers import l1_l2

# %%
from statistics import stdev

def Average(data):
    return sum(data) / len(data)

# Z-Scores
def normalize_series(data, mean, std):
    data = data - mean
    data = data / std
    return data

def inverse_normalize_series(data, mean, std):
    data = data * std
    data = data + mean
    return data

# %%
def model_forecast(model, series, window_size, batch_size):
   ds = tf.data.Dataset.from_tensor_slices(series)
   ds = ds.window(window_size, shift=1, drop_remainder=True)
   ds = ds.flat_map(lambda w: w.batch(window_size))
   ds = ds.batch(batch_size, drop_remainder=True).prefetch(1)
   forecast = model.predict(ds)
   return forecast

# %%
# Datetime
def datetime_range(start, end, delta):
    current = start
    while current < end:
        yield current
        current += delta

# %%
# Multisteps Forecast
def multi_step_forecasts(n_lookback, n_forecast, model, data, data_scaled):

    input_forecast = data_scaled[-n_lookback:]
    x_forecast = input_forecast.reshape(1, n_lookback, 1)

    y_future = [] # predicted target values

    for i in range(n_forecast):
        # generate the next forecast
        output = model.predict(x_forecast)

        # transform the forecasts back to the original scale
        normal_output = inverse_normalize_series(output, Average(data), stdev(data.flatten()))

        # save the forecast
        y_future.append(list(normal_output[0]))

        # feed the last forecast back to the model as an input
        x_forecast = np.append(x_forecast, output.flatten()[0])

        # reshape to fit the input model
        x_forecast = x_forecast[-n_lookback:].reshape(1, n_lookback, 1)


    return y_future

# %%
df = pd.read_csv("/content/BMRI.JK Close.csv",sep=";")

# %%
df['Date'] = df['Date'].apply(pd.to_datetime)
df.info()
# Out:
# <ipython-input-9-fe3be03317d7>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = df['Date'].apply(pd.to_datetime)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2726 entries, 0 to 2725
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2726 non-null   datetime64[ns]
#  1   Close   2726 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 42.7 KB

# %%
df.head()
# Out:
#         Date  Close
# 0 2013-02-01   2062
# 1 2013-03-01   2050
# 2 2013-04-01   2062
# 3 2013-07-01   2050
# 4 2013-08-01   2087

# %%
dataSize = len(df)
print(dataSize)
# Out:
# 2726

# %%
# Membuat date sequence

dataset_date = [dt.strftime('%Y-%m-%d') for dt in
       datetime_range(datetime(2013,2,1), datetime(2023,12,29),
       relativedelta(days=1))]

print(len(df))
print(np.shape(dataset_date))
# Out:
# 2726
# (3983,)

# %%
# Mengonversi Skalar/Array/Series Menjadi Objek DateTime
# Ensure that the length of dataset_date matches the length of df
#dataset_date = dataset_date[:len(df)]  # Trim dataset_date to match df length

#df['Date'] = dataset_date
#df['Date'] = df['Date'].apply(pd.to_datetime)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2726 entries, 0 to 2725
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2726 non-null   datetime64[ns]
#  1   Close   2726 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 42.7 KB

# %%
# Plot Data
plt.subplots(figsize=(15, 6))
sns.lineplot(x="Date", y="Close", data=df, label='Harga Saham BMRI')
plt.xlabel('Periode Waktu')
plt.ylabel('Harga Saham')
plt.legend(loc='upper left', prop={'size': 16})
plt.grid()
plt.show()

# %%
# Mengetahui Summary dari Dataset
df.describe()
# Out:
#                                 Date        Close
# count                           2726  2726.000000
# mean   2018-06-30 05:27:30.770359296  3289.028247
# min              2013-01-02 00:00:00  1662.000000
# 25%              2015-10-13 12:00:00  2537.000000
# 50%              2018-06-30 12:00:00  3137.000000
# 75%              2021-03-17 18:00:00  3762.000000
# max              2023-12-29 00:00:00  6125.000000
# std                              NaN   960.917836

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df['Close'],lags=25)

# %%
# Menentukan Timestep yang Akan Dipakai
n_lookback = 90

# %%
# Menentukan Proporsi Pembagian Data Training dan Data Testing
SPLIT_TIME_TRAIN_VAL = int(math.floor(0.75*((len(df))/n_lookback)) * n_lookback)
SPLIT_TIME_TRAIN_VAL
# Out:
# 1980

# %%
data_train = df[:SPLIT_TIME_TRAIN_VAL]['Close']
data_train = pd.DataFrame(data_train)
data_train.index = df[:SPLIT_TIME_TRAIN_VAL]['Date']

data_val = df[SPLIT_TIME_TRAIN_VAL:]['Close']
data_val = pd.DataFrame(data_val)
data_val.index = df[SPLIT_TIME_TRAIN_VAL:]['Date']

print(len(data_train)/len(df))
print(len(data_val)/len(df))
# Out:
# 0.7263389581804842
# 0.2736610418195158

# %%
# Melihat Data Training/Pelatihan
data_train.head()
# Out:
#             Close
# Date
# 2013-02-01   2062
# 2013-03-01   2050
# 2013-04-01   2062
# 2013-07-01   2050
# 2013-08-01   2087

# %%
# Plot Pembagian Data Training dan Data Testing
plt.subplots(figsize = (18,6))
ax=sns.lineplot(x="Date", y="Close",
             data=data_train, drawstyle='steps-post', label='Data Pelatihan')
ax=sns.lineplot(x="Date", y="Close",
             data=data_val, drawstyle='steps-post', label='Data Pengujian')
plt.legend(loc='upper left', prop={'size': 16})
plt.xlabel('Tahun', fontsize=15); plt.ylabel('Harga Saham BMRI', fontsize=15)
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=15)
plt.grid()

# %%
# Mengubah Dimensi Dataset
bmri = df["Close"].values.reshape(-1, 1)

bmri_train = data_train.values.reshape(-1, 1)

bmri_val = data_val.values.reshape(-1, 1)

print(bmri_train.shape);print(bmri_val.shape)
# Out:
# (1980, 1)
# (746, 1)

# %%
# Melihat Data Pelatihan yang Sudah Diubah Dimensinya
bmri_train[:5]
# Out:
# array([[2062],
#        [2050],
#        [2062],
#        [2050],
#        [2087]])

# %%
# Membuat Variabel Baru x_train dan y_train
x_train = []
y_train = []

for i in range(n_lookback, len(bmri_train)):
    x_train.append(bmri_train[i - n_lookback: i])
    y_train.append(bmri_train[i])

x_train = np.array(x_train)
y_train = np.array(y_train)
print(x_train.shape)
print(y_train.shape)
# Out:
# (1890, 90, 1)
# (1890, 1)

# %%
# Membuat Variabel Baru x_val dan y_val
x_val = []
y_val = []

for i in range(n_lookback, len(bmri_val)):
    x_val.append(bmri_val[i - n_lookback: i])
    y_val.append(bmri_val[i])

x_val = np.array(x_val)
y_val = np.array(y_val)
print(x_val.shape)
print(y_val.shape)
# Out:
# (656, 90, 1)
# (656, 1)

# %%
# Scalling Dataset
bmri_scaled = normalize_series(bmri, Average(bmri), stdev(bmri.flatten()))

bmri_train_scaled = normalize_series(bmri_train, Average(bmri_train), stdev(bmri_train.flatten()))

bmri_val_scaled = normalize_series(bmri_val, Average(bmri_val), stdev(bmri_val.flatten()))

# %%
# Data Sebelum Dilakukan Scalling
bmri[0:5]
# Out:
# array([[2062],
#        [2050],
#        [2062],
#        [2050],
#        [2087]])

# %%
# Data Sesudah Dilakukan Scalling
bmri_scaled[0:5]
# Out:
# array([[-1.27693363],
#        [-1.2894217 ],
#        [-1.27693363],
#        [-1.2894217 ],
#        [-1.25091684]])

# %%
# Membuat Feature dan label Untuk Data Pelatihan Dari Data yang Sudah Discalling
x_train_scaled = []
y_train_scaled = []

for i in range(n_lookback, len(bmri_train_scaled)):
    x_train_scaled.append(bmri_train_scaled[i - n_lookback: i])
    y_train_scaled.append(bmri_train_scaled[i])

x_train_scaled = np.array(x_train_scaled)
y_train_scaled = np.array(y_train_scaled)
print(x_train_scaled.shape)
print(y_train_scaled.shape)
# Out:
# (1890, 90, 1)
# (1890, 1)

# %%
# Melihat Dimensi Dari Data Pertama
print(x_train[0].shape)
# Out:
# (90, 1)

# %%
# Membuat Feature dan label Untuk Data Pengujian Dari Data yang Sudah Di scalling
x_val_scaled = []
y_val_scaled = []

for i in range(n_lookback, len(bmri_val_scaled)):
    x_val_scaled.append(bmri_val_scaled[i - n_lookback: i])
    y_val_scaled.append(bmri_val_scaled[i])

x_val_scaled = np.array(x_val_scaled)
y_val_scaled = np.array(y_val_scaled)
print(x_val_scaled.shape)
print(y_val_scaled.shape)
# Out:
# (656, 90, 1)
# (656, 1)

# %%
# Membuat Arsitektur Model yang Akan Digunakan

# Model LSTM
model = Sequential()
model.add(LSTM(64, return_sequences=False, activation='relu', kernel_regularizer=l1_l2(l1=0.01, l2=0.5), input_shape=(n_lookback,1)))
model.add(Dense(1))
model.compile(loss='huber', optimizer=Adam(learning_rate=0.00005))

# %%
# Menentukan File Tujuan Untuk Menyimpan Bobot Model
filepath = "best_model.h5"

# Membuat ModelCheckpoint Callback Untuk Menyimpan Bobot Model
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath,
                                                save_best_only=True,
                                                save_weights_only=True,
                                                monitor='val_loss',
                                                mode='min')

# Membuat Konfigurasi EarlyStopping Callback yang Berfungsi Untuk Memberhentikan Proses Training Ketika Nilai Loss Berhenti Membaik
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

# Fit the model to the data
history = model.fit(x_train_scaled, y_train_scaled, epochs=2000, validation_data=(x_val_scaled, y_val_scaled) ,batch_size=64,verbose=1, callbacks=[checkpoint, early_stopping])
# Out:
# Epoch 1/2000
# 30/30 [==============================] - 3s 56ms/step - loss: 1.7853 - val_loss: 1.7562
# Epoch 2/2000
# 30/30 [==============================] - 1s 44ms/step - loss: 1.7269 - val_loss: 1.6978
# Epoch 3/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.6701 - val_loss: 1.6418
# Epoch 4/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.6151 - val_loss: 1.5867
# Epoch 5/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.5602 - val_loss: 1.5307
# Epoch 6/2000
# 30/30 [==============================] - 2s 65ms/step - loss: 1.5037 - val_loss: 1.4720
# Epoch 7/2000
# 30/30 [==============================] - 2s 66ms/step - loss: 1.4427 - val_loss: 1.4067
# Epoch 8/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 1.3740 - val_loss: 1.3309
# Epoch 9/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.2860 - val_loss: 1.2290
# Epoch 10/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.2111 - val_loss: 1.1724
# Epoch 11/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 1.1476 - val_loss: 1.1273
# Epoch 12/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.1169 - val_loss: 1.0954
# Epoch 13/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 1.0933 - val_loss: 1.0811
# Epoch 14/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 1.0650 - val_loss: 1.0439
# Epoch 15/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 1.0316 - val_loss: 1.0109
# Epoch 16/2000
# 30/30 [==============================] - 2s 63ms/step - loss: 1.0120 - val_loss: 1.0000
# Epoch 17/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.9906 - val_loss: 0.9720
# Epoch 18/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.9663 - val_loss: 0.9457
# Epoch 19/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.9458 - val_loss: 0.9278
# Epoch 20/2000
# 30/30 [==============================] - 1s 44ms/step - loss: 0.9250 - val_loss: 0.9058
# Epoch 21/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.9053 - val_loss: 0.8859
# Epoch 22/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.8866 - val_loss: 0.8672
# Epoch 23/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.8665 - val_loss: 0.8463
# Epoch 24/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.8476 - val_loss: 0.8279
# Epoch 25/2000
# 30/30 [==============================] - 2s 62ms/step - loss: 0.8292 - val_loss: 0.8086
# Epoch 26/2000
# 30/30 [==============================] - 2s 51ms/step - loss: 0.8110 - val_loss: 0.7899
# Epoch 27/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.7940 - val_loss: 0.7725
# Epoch 28/2000
# 30/30 [==============================] - 2s 56ms/step - loss: 0.7757 - val_loss: 0.7549
# Epoch 29/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.7586 - val_loss: 0.7371
# Epoch 30/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.7416 - val_loss: 0.7197
# Epoch 31/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.7249 - val_loss: 0.7032
# Epoch 32/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.7086 - val_loss: 0.6876
# Epoch 33/2000
# 30/30 [==============================] - 2s 59ms/step - loss: 0.6927 - val_loss: 0.6712
# Epoch 34/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6769 - val_loss: 0.6553
# Epoch 35/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.6614 - val_loss: 0.6397
# Epoch 36/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6464 - val_loss: 0.6251
# Epoch 37/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6315 - val_loss: 0.6106
# Epoch 38/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.6170 - val_loss: 0.5957
# Epoch 39/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.6027 - val_loss: 0.5814
# Epoch 40/2000
# 30/30 [==============================] - 2s 50ms/step - loss: 0.5887 - val_loss: 0.5681
# Epoch 41/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.5751 - val_loss: 0.5544
# Epoch 42/2000
# 30/30 [==============================] - 2s 53ms/step - loss: 0.5616 - val_loss: 0.5410
# Epoch 43/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.5484 - val_loss: 0.5281
# Epoch 44/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.5354 - val_loss: 0.5155
# Epoch 45/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.5227 - val_loss: 0.5026
# Epoch 46/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.5102 - val_loss: 0.4907
# Epoch 47/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.4980 - val_loss: 0.4789
# Epoch 48/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.4860 - val_loss: 0.4670
# Epoch 49/2000
# 30/30 [==============================] - 2s 56ms/step - loss: 0.4743 - val_loss: 0.4555
# Epoch 50/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.4628 - val_loss: 0.4440
# Epoch 51/2000
# 30/30 [==============================] - 2s 73ms/step - loss: 0.4515 - val_loss: 0.4332
# Epoch 52/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.4405 - val_loss: 0.4223
# Epoch 53/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.4297 - val_loss: 0.4121
# Epoch 54/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.4196 - val_loss: 0.4030
# Epoch 55/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.4095 - val_loss: 0.3920
# Epoch 56/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.3989 - val_loss: 0.3819
# Epoch 57/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.3890 - val_loss: 0.3724
# Epoch 58/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.3794 - val_loss: 0.3634
# Epoch 59/2000
# 30/30 [==============================] - 2s 63ms/step - loss: 0.3700 - val_loss: 0.3540
# Epoch 60/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.3609 - val_loss: 0.3452
# Epoch 61/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.3519 - val_loss: 0.3364
# Epoch 62/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.3431 - val_loss: 0.3278
# Epoch 63/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.3344 - val_loss: 0.3193
# Epoch 64/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.3260 - val_loss: 0.3112
# Epoch 65/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.3177 - val_loss: 0.3031
# Epoch 66/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.3096 - val_loss: 0.2953
# Epoch 67/2000
# 30/30 [==============================] - 2s 74ms/step - loss: 0.3017 - val_loss: 0.2873
# Epoch 68/2000
# 30/30 [==============================] - 2s 61ms/step - loss: 0.2939 - val_loss: 0.2799
# Epoch 69/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2864 - val_loss: 0.2723
# Epoch 70/2000
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2790 - val_loss: 0.2653
# Epoch 71/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2717 - val_loss: 0.2579
# Epoch 72/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2646 - val_loss: 0.2513
# Epoch 73/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2578 - val_loss: 0.2443
# Epoch 74/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.2513 - val_loss: 0.2379
# Epoch 75/2000
# 30/30 [==============================] - 2s 55ms/step - loss: 0.2446 - val_loss: 0.2313
# Epoch 76/2000
# 30/30 [==============================] - 2s 73ms/step - loss: 0.2382 - val_loss: 0.2253
# Epoch 77/2000
# 30/30 [==============================] - 1s 49ms/step - loss: 0.2320 - val_loss: 0.2191
# Epoch 78/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2260 - val_loss: 0.2132
# Epoch 79/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.2200 - val_loss: 0.2073
# Epoch 80/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2142 - val_loss: 0.2015
# Epoch 81/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2086 - val_loss: 0.1960
# Epoch 82/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.2031 - val_loss: 0.1909
# Epoch 83/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1976 - val_loss: 0.1852
# Epoch 84/2000
# 30/30 [==============================] - 2s 61ms/step - loss: 0.1924 - val_loss: 0.1804
# Epoch 85/2000
# 30/30 [==============================] - 2s 73ms/step - loss: 0.1873 - val_loss: 0.1756
# Epoch 86/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1822 - val_loss: 0.1705
# Epoch 87/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.1772 - val_loss: 0.1654
# Epoch 88/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1724 - val_loss: 0.1606
# Epoch 89/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1677 - val_loss: 0.1563
# Epoch 90/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1631 - val_loss: 0.1515
# Epoch 91/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1586 - val_loss: 0.1474
# Epoch 92/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1541 - val_loss: 0.1430
# Epoch 93/2000
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1498 - val_loss: 0.1390
# Epoch 94/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.1456 - val_loss: 0.1350
# Epoch 95/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1415 - val_loss: 0.1311
# Epoch 96/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1379 - val_loss: 0.1278
# Epoch 97/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1343 - val_loss: 0.1239
# Epoch 98/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1302 - val_loss: 0.1196
# Epoch 99/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.1265 - val_loss: 0.1163
# Epoch 100/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1231 - val_loss: 0.1127
# Epoch 101/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1198 - val_loss: 0.1099
# Epoch 102/2000
# 30/30 [==============================] - 2s 78ms/step - loss: 0.1229 - val_loss: 0.1190
# Epoch 103/2000
# 30/30 [==============================] - 2s 81ms/step - loss: 0.1227 - val_loss: 0.1075
# Epoch 104/2000
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1141 - val_loss: 0.1023
# Epoch 105/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1103 - val_loss: 0.0992
# Epoch 106/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1067 - val_loss: 0.0967
# Epoch 107/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1036 - val_loss: 0.0940
# Epoch 108/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1010 - val_loss: 0.0914
# Epoch 109/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0982 - val_loss: 0.0891
# Epoch 110/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0961 - val_loss: 0.0863
# Epoch 111/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0934 - val_loss: 0.0839
# Epoch 112/2000
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0912 - val_loss: 0.0817
# Epoch 113/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0889 - val_loss: 0.0800
# Epoch 114/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0869 - val_loss: 0.0774
# Epoch 115/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0842 - val_loss: 0.0748
# Epoch 116/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0819 - val_loss: 0.0726
# Epoch 117/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0801 - val_loss: 0.0711
# Epoch 118/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0783 - val_loss: 0.0688
# Epoch 119/2000
# 30/30 [==============================] - 1s 50ms/step - loss: 0.0758 - val_loss: 0.0674
# Epoch 120/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0746 - val_loss: 0.0653
# Epoch 121/2000
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0731 - val_loss: 0.0658
# Epoch 122/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0717 - val_loss: 0.0619
# Epoch 123/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0686 - val_loss: 0.0598
# Epoch 124/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0681 - val_loss: 0.0594
# Epoch 125/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0658 - val_loss: 0.0565
# Epoch 126/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0642 - val_loss: 0.0553
# Epoch 127/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0632 - val_loss: 0.0537
# Epoch 128/2000
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0609 - val_loss: 0.0520
# Epoch 129/2000
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0599 - val_loss: 0.0509
# Epoch 130/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0577 - val_loss: 0.0489
# Epoch 131/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0566 - val_loss: 0.0478
# Epoch 132/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0556 - val_loss: 0.0470
# Epoch 133/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.1240 - val_loss: 0.1171
# Epoch 134/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.1126 - val_loss: 0.0926
# Epoch 135/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0920 - val_loss: 0.0680
# Epoch 136/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0731 - val_loss: 0.0518
# Epoch 137/2000
# 30/30 [==============================] - 2s 62ms/step - loss: 0.0677 - val_loss: 0.0519
# Epoch 138/2000
# 30/30 [==============================] - 2s 67ms/step - loss: 0.0650 - val_loss: 0.0494
# Epoch 139/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0629 - val_loss: 0.0485
# Epoch 140/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0609 - val_loss: 0.0480
# Epoch 141/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0590 - val_loss: 0.0467
# Epoch 142/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0571 - val_loss: 0.0461
# Epoch 143/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0558 - val_loss: 0.0451
# Epoch 144/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0544 - val_loss: 0.0439
# Epoch 145/2000
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0528 - val_loss: 0.0432
# Epoch 146/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0520 - val_loss: 0.0422
# Epoch 147/2000
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0508 - val_loss: 0.0428
# Epoch 148/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0504 - val_loss: 0.0433
# Epoch 149/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0499 - val_loss: 0.0406
# Epoch 150/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0489 - val_loss: 0.0408
# Epoch 151/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0490 - val_loss: 0.0392
# Epoch 152/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0473 - val_loss: 0.0392
# Epoch 153/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0474 - val_loss: 0.0386
# Epoch 154/2000
# 30/30 [==============================] - 2s 54ms/step - loss: 0.0466 - val_loss: 0.0394
# Epoch 155/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0459 - val_loss: 0.0384
# Epoch 156/2000
# 30/30 [==============================] - 2s 58ms/step - loss: 0.0450 - val_loss: 0.0370
# Epoch 157/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0454 - val_loss: 0.0365
# Epoch 158/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0447 - val_loss: 0.0370
# Epoch 159/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0444 - val_loss: 0.0370
# Epoch 160/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0437 - val_loss: 0.0352
# Epoch 161/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0433 - val_loss: 0.0350
# Epoch 162/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0436 - val_loss: 0.0347
# Epoch 163/2000
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0426 - val_loss: 0.0337
# Epoch 164/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0425 - val_loss: 0.0334
# Epoch 165/2000
# 30/30 [==============================] - 2s 51ms/step - loss: 0.0432 - val_loss: 0.0333
# Epoch 166/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0419 - val_loss: 0.0347
# Epoch 167/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0412 - val_loss: 0.0354
# Epoch 168/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0408 - val_loss: 0.0329
# Epoch 169/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0408 - val_loss: 0.0325
# Epoch 170/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0410 - val_loss: 0.0327
# Epoch 171/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0391 - val_loss: 0.0314
# Epoch 172/2000
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0384 - val_loss: 0.0308
# Epoch 173/2000
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0390 - val_loss: 0.0304
# Epoch 174/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0387 - val_loss: 0.0309
# Epoch 175/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0381 - val_loss: 0.0300
# Epoch 176/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0375 - val_loss: 0.0304
# Epoch 177/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0377 - val_loss: 0.0322
# Epoch 178/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0472 - val_loss: 0.0312
# Epoch 179/2000
# 30/30 [==============================] - 2s 59ms/step - loss: 0.0385 - val_loss: 0.0295
# Epoch 180/2000
# 30/30 [==============================] - 2s 77ms/step - loss: 0.0371 - val_loss: 0.0318
# Epoch 181/2000
# 30/30 [==============================] - 2s 79ms/step - loss: 0.0368 - val_loss: 0.0288
# Epoch 182/2000
# 30/30 [==============================] - 2s 55ms/step - loss: 0.0364 - val_loss: 0.0289
# Epoch 183/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0379 - val_loss: 0.0291
# Epoch 184/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0353 - val_loss: 0.0283
# Epoch 185/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0374 - val_loss: 0.0282
# Epoch 186/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0348 - val_loss: 0.0284
# Epoch 187/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0348 - val_loss: 0.0271
# Epoch 188/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0343 - val_loss: 0.0288
# Epoch 189/2000
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0341 - val_loss: 0.0321
# Epoch 190/2000
# 30/30 [==============================] - 2s 74ms/step - loss: 0.0361 - val_loss: 0.0264
# Epoch 191/2000
# 30/30 [==============================] - 2s 50ms/step - loss: 0.0346 - val_loss: 0.0264
# Epoch 192/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0335 - val_loss: 0.0272
# Epoch 193/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0344 - val_loss: 0.0259
# Epoch 194/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0335 - val_loss: 0.0263
# Epoch 195/2000
# 30/30 [==============================] - 1s 48ms/step - loss: 0.0336 - val_loss: 0.0251
# Epoch 196/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0333 - val_loss: 0.0270
# Epoch 197/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0325 - val_loss: 0.0265
# Epoch 198/2000
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0331 - val_loss: 0.0258
# Epoch 199/2000
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0330 - val_loss: 0.0251
# Epoch 200/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0326 - val_loss: 0.0275
# Epoch 201/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0325 - val_loss: 0.0246
# Epoch 202/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0329 - val_loss: 0.0305
# Epoch 203/2000
# 30/30 [==============================] - 2s 68ms/step - loss: 0.0327 - val_loss: 0.0244
# Epoch 204/2000
# 30/30 [==============================] - 2s 73ms/step - loss: 0.0316 - val_loss: 0.0239
# Epoch 205/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0314 - val_loss: 0.0242
# Epoch 206/2000
# 30/30 [==============================] - 2s 72ms/step - loss: 0.0318 - val_loss: 0.0239
# Epoch 207/2000
# 30/30 [==============================] - 2s 61ms/step - loss: 0.0312 - val_loss: 0.0239
# Epoch 208/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0341 - val_loss: 0.0254
# Epoch 209/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0325 - val_loss: 0.0234
# Epoch 210/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0317 - val_loss: 0.0264
# Epoch 211/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0306 - val_loss: 0.0240
# Epoch 212/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0303 - val_loss: 0.0251
# Epoch 213/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0302 - val_loss: 0.0235
# Epoch 214/2000
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0307 - val_loss: 0.0272
# Epoch 215/2000
# 30/30 [==============================] - 2s 76ms/step - loss: 0.0311 - val_loss: 0.0226
# Epoch 216/2000
# 30/30 [==============================] - 2s 52ms/step - loss: 0.0302 - val_loss: 0.0235
# Epoch 217/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0302 - val_loss: 0.0219
# Epoch 218/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0296 - val_loss: 0.0228
# Epoch 219/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0309 - val_loss: 0.0230
# Epoch 220/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0303 - val_loss: 0.0223
# Epoch 221/2000
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0301 - val_loss: 0.0222
# Epoch 222/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0318 - val_loss: 0.0239
# Epoch 223/2000
# 30/30 [==============================] - 2s 63ms/step - loss: 0.0322 - val_loss: 0.0226
# Epoch 224/2000
# 30/30 [==============================] - 2s 71ms/step - loss: 0.0311 - val_loss: 0.0227
# Epoch 225/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0350 - val_loss: 0.0406
# Epoch 226/2000
# 30/30 [==============================] - 1s 47ms/step - loss: 0.0361 - val_loss: 0.0256
# Epoch 227/2000
# 30/30 [==============================] - 1s 46ms/step - loss: 0.0300 - val_loss: 0.0227

# %%
# Plot Loss Dari Model Peramalan
plt.figure(figsize=[18,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss','Validation loss'],fontsize=18)
plt.xlabel('Epoch', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Training and Validation loss',fontsize=16)
plt.show()

# %%
forecast_train_data = model_forecast(model,bmri_train_scaled, n_lookback, 1)
print(forecast_train_data.shape)

forecast_train_data = forecast_train_data[:-1, 0]
print(forecast_train_data.shape)
print(bmri_train_scaled.shape[0]-n_lookback)
# Out:
# 1891/1891 [==============================] - 14s 8ms/step
# (1891, 1)
# (1890,)
# 1890

# %%
forecast_train_data = inverse_normalize_series(forecast_train_data, Average(bmri_train), stdev(bmri_train.flatten()))
forecast_train_data[:5]
# Out:
# array([2559.601131  , 2554.20296816, 2549.96200136, 2545.25661806,
#        2539.50347475])

# %%
actual = np.squeeze(bmri_train[-forecast_train_data.shape[0]:])
print(actual.shape)
print(actual[:5])
# Out:
# (1890,)
# [2537 2537 2512 2512 2600]

# %%
df_train = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_train['Date'] = data_train[-forecast_train_data.shape[0]:].index
df_train['Forecast'] = forecast_train_data
df_train['Actual'] = actual
df_train
# Out:
#            Date  Actual     Forecast
# 0    2013-05-14    2537  2559.601131
# 1    2013-05-15    2537  2554.202968
# 2    2013-05-16    2512  2549.962001
# 3    2013-05-17    2512  2545.256618
# 4    2013-05-20    2600  2539.503475
# ...         ...     ...          ...
# 1885 2020-01-12    3262  3270.974514
# 1886 2020-02-12    3325  3279.988246
# 1887 2020-03-12    3287  3290.345790
# 1888 2020-04-12    3300  3301.141353
# 1889 2020-07-12    3350  3310.028316
#
# [1890 rows x 3 columns]

# %%
plt.subplots(figsize=(18, 6))
ax = sns.lineplot(x="Date", y="Actual", data=df_train,
                    label="Data Latih Aktual", marker='.', color = 'red')
ax = sns.lineplot(x="Date", y="Forecast", data=df_train,
                    label="Prakiraan Data Latih", marker='.', linestyle="--", color = 'darkslateblue')
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BMRI')
plt.title("Grafik Data Aktual dan Hasil Prakiraan dari Data Latih (Train Data)\n", fontsize = 15)
plt.legend(loc='upper left')

# %%
rmse = mean_squared_error(df_train['Forecast'], df_train['Actual'], squared=False)
mae = mean_absolute_error(df_train['Forecast'], df_train['Actual'])
mape = mean_absolute_percentage_error(df_train['Forecast'], df_train['Actual'])

print('Forecast Train Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Train Accuracy
# RMSE:  105.3447
# MAE:  72.9088
# MAPE:  0.025778

# %%
forecast_val_data = model_forecast(model, bmri_val_scaled, n_lookback, 1)
print(forecast_val_data.shape)

forecast_val_data = forecast_val_data[:-1, 0]
print(forecast_val_data.shape)
print(bmri_val_scaled.shape[0]-n_lookback)
# Out:
# 657/657 [==============================] - 5s 8ms/step
# (657, 1)
# (656,)
# 656

# %%
forecast_val_data = inverse_normalize_series(forecast_val_data, Average(bmri_val), stdev(bmri_val.flatten()))
forecast_val_data[:5]
# Out:
# array([3114.36517874, 3101.15289847, 3085.57684866, 3068.12579886,
#        3057.29974905])

# %%
actual = np.squeeze(bmri_val[-forecast_val_data.shape[0]:])
print(actual.shape)
print(actual[:5])
# Out:
# (656,)
# [3075 2987 3025 3100 3112]

# %%
len(data_val[-forecast_val_data.shape[0]:])
# Out:
# 656

# %%
df_val = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])
df_val['Date'] = data_val[-forecast_val_data.shape[0]:].index
df_val['Forecast'] = forecast_val_data
df_val['Actual'] = actual
df_val
# Out:
#           Date  Actual     Forecast
# 0   2021-04-23    3075  3114.365179
# 1   2021-04-26    2987  3101.152898
# 2   2021-04-27    3025  3085.576849
# 3   2021-04-28    3100  3068.125799
# 4   2021-04-29    3112  3057.299749
# ..         ...     ...          ...
# 651 2023-12-21    5975  5865.385320
# 652 2023-12-22    5975  5885.509588
# 653 2023-12-27    6000  5905.469915
# 654 2023-12-28    6125  5924.383733
# 655 2023-12-29    6050  5948.029363
#
# [656 rows x 3 columns]

# %%
plt.subplots(figsize=(18, 6))
ax = sns.lineplot(x="Date", y="Actual", data=df_val,
                    label="Data Validasi Aktual", marker='.', color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_val,
                    label="Prakiraan Data Validasi", marker='.', linestyle="--", color='darkslategrey')
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BMRI')
plt.title("Grafik Data Aktual dan Hasil Prakiraan dari Data Validasi (Validation Data)\n", fontsize = 15)
plt.legend(loc='upper left')

# %%
rmse = mean_squared_error(df_val['Forecast'], df_val['Actual'], squared=False)
mae = mean_absolute_error(df_val['Forecast'], df_val['Actual'])
mape = mean_absolute_percentage_error(df_val['Forecast'], df_val['Actual'])

print('Forecast Val Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Val Accuracy
# RMSE:  112.6005
# MAE:  84.3545
# MAPE:  0.019651

# %%
rmse = mean_squared_error(df_train['Forecast'], df_train['Actual'], squared=False)
mae = mean_absolute_error(df_train['Forecast'], df_train['Actual'])
mape = mean_absolute_percentage_error(df_train['Forecast'], df_train['Actual'])

print('Forecast Train Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))

rmse = mean_squared_error(df_val['Forecast'], df_val['Actual'], squared=False)
mae = mean_absolute_error(df_val['Forecast'], df_val['Actual'])
mape = mean_absolute_percentage_error(df_val['Forecast'], df_val['Actual'])

print('Forecast Val Accuracy')
print('RMSE: ', round(rmse,4))
print('MAE: ', round(mae,4))
print('MAPE: ', round(mape,6))
# Out:
# Forecast Train Accuracy
# RMSE:  105.3447
# MAE:  72.9088
# MAPE:  0.025778
# Forecast Val Accuracy
# RMSE:  112.6005
# MAE:  84.3545
# MAPE:  0.019651

# %%
# Meramalkan Untuk 15 Periode Ke Depan
forecast_values = multi_step_forecasts(n_lookback=n_lookback, n_forecast=727, model=model, data=bmri, data_scaled=bmri_scaled)
# Out:
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step

# %%
# Rentang Tanggal Yang Akan Diramal
date_forecast = [dt.strftime('%Y-%m-%d') for dt in
       datetime_range(datetime(2024, 1, 2), datetime(2025, 12, 29),
       relativedelta(days=1))]

print(np.shape(date_forecast))
# Out:
# (727,)

# %%
# Hasil Peramalan
df_forecast = pd.DataFrame(columns=['Date', 'Forecast'])
df_forecast['Date'] = date_forecast
df_forecast['Date'] = pd.to_datetime(df_forecast['Date'])
df_forecast['Forecast'] = np.squeeze(forecast_values)
df_forecast
# Out:
#           Date     Forecast
# 0   2024-01-02  4836.708911
# 1   2024-01-03  4812.779955
# 2   2024-01-04  4769.273852
# 3   2024-01-05  4718.462206
# 4   2024-01-06  4662.856127
# ..         ...          ...
# 722 2025-12-24  4736.885790
# 723 2025-12-25  4740.136035
# 724 2025-12-26  4743.527392
# 725 2025-12-27  4747.053027
# 726 2025-12-28  4750.694018
#
# [727 rows x 2 columns]

# %%
# Plot Hasil Peramalan
from turtle import color

plt.subplots(figsize = (18,6))
sns.lineplot(x="Date", y="Forecast",
             data=df_forecast, marker='.', color = 'blue')
plt.title("Harga Saham BMRI 2 Januari 2024 - 29 Desember 2024")
plt.grid()

# %%
# Plot Data Aktual dan Hasil Peramalan
fig, ax = plt.subplots(figsize = (25,8))
ax = sns.lineplot(x="Date", y="Actual", data=df_train,
                    label="Data Latih Aktual", marker='.', color='red')
ax = sns.lineplot(x="Date", y="Forecast", data=df_train,
                    label="Prakiraan Data Latih", marker='.', linestyle="--", color='darkslateblue')
ax = sns.lineplot(x="Date", y="Actual", data=df_val,
                    label="Data Validasi Aktual", marker='.', color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_val,
                    label="Prakiraan Data Validasi", marker='.', linestyle="--", color='darkslategrey')
ax = sns.lineplot(x="Date", y="Forecast", data=df_forecast,
                    label="Hasil Prakiraan", marker='.', color = 'blue')
plt.grid()
plt.xlabel('Tanggal'); plt.ylabel('Harga Saham BMRI')
plt.title("Grafik Harga Saham BMRI\n", fontsize = 20)
plt.legend(loc='upper left')

# %%
fig, ax = plt.subplots(figsize = (18,6))
ax = sns.lineplot(x="Date", y="Close", data=df,
                    label="Data Aktual", color='sandybrown')
ax = sns.lineplot(x="Date", y="Forecast", data=df_forecast,
                    label="Hasil Prakiraan", color='blue')
plt.title("Grafik Data Aktual dan Hasil Prakiraan\n", fontsize = 20)
plt.xlabel('Tahun'); plt.ylabel('Harga Saham BMRI')
plt.grid()
